# %%
import http.server
import socketserver

PORT = 8000
handler = http.server.SimpleHTTPRequestHandler

with socketserver.TCPServer(("", PORT), handler) as http:
    print("File Transfer Server Running on Port", PORT)
    print("Open this in your browser:  http://localhost:8000")
    http.serve_forever()
# Out:
# File Transfer Server Running on Port 8000
# Open this in your browser:  http://localhost:8000
# 127.0.0.1 - - [27/Nov/2025 09:05:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2025 09:05:04] code 404, message File not found
# 127.0.0.1 - - [27/Nov/2025 09:05:04] "GET /favicon.ico HTTP/1.1" 404 -
